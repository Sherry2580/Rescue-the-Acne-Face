# %% [markdown]
# ## Add acne to face

# %%
import cv2
import numpy as np
import os

def process_images(input_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')): 
            image_path = os.path.join(input_folder, filename)
            image = cv2.imread(image_path)
            if image is not None:
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                faces = detect_faces(image)
                processed_image = simulate_acne_on_faces(image, faces, num_acne=50, min_size=3, max_size=12)
                output_image_path = os.path.join(output_folder, filename)
                cv2.imwrite(output_image_path, cv2.cvtColor(processed_image, cv2.COLOR_RGB2BGR))

# 偵測臉部區域
def detect_faces(image):
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)
    return faces

# 偵測眼睛位置
def detect_eyes(image, face):
    eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')
    (x, y, w, h) = face
    roi_gray = image[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray, scaleFactor=1.1, minNeighbors=10)
    return [(ex+x, ey+y, ew, eh) for (ex, ey, ew, eh) in eyes]

# 在臉部區域隨機撒模擬痘痘
def simulate_acne_on_faces(image, faces, num_acne=5, min_size=5, max_size=20):
    output = image.copy()
    for (x, y, w, h) in faces:
        face_center_region = (x + int(w * 0.15), y + int(h * 0.2), int(w * 0.7), int(h * 0.6))
        fx, fy, fw, fh = face_center_region
        eyes = detect_eyes(image, (x, y, w, h))
        for _ in range(num_acne):
            valid = False
            while not valid:
                center_x = np.random.randint(fx, fx + fw)
                center_y = np.random.randint(fy, fy + fh)
                size = np.random.randint(min_size, max_size)
                valid = True
                # 確認痘痘不要長在眼睛上
                for (ex, ey, ew, eh) in eyes:
                    if (ex < center_x < ex + ew) and (ey < center_y < ey + eh):
                        valid = False
                        break
                if not (fx <= center_x - size and center_x + size <= fx + fw and fy <= center_y - size and center_y + size <= fy + fh):
                    valid = False
            random_value = np.random.rand()
            if random_value < 0.33:
                color = (139, 62, 47) 
            elif random_value < 0.66:
                color = (205, 112, 84)
            else:
                color = (238, 106, 80)
            cv2.circle(output, (center_x, center_y), size, color, -1)
    return output

input_folder = 'All_image'
output_folder = 'New_image'
process_images(input_folder, output_folder)

# %% [markdown]
# ## Cut and resized images

# %%
import cv2
import os
import numpy as np

source_folder = './noacne_white_background_2444_1718_541/'
target_folder = './noacne_white_background_1024_1024_541/'

if not os.path.exists(target_folder):
    os.makedirs(target_folder)

for filename in os.listdir(source_folder):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
        image_path = os.path.join(source_folder, filename)
        image = cv2.imread(image_path)
        if image is None:
            continue
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # 設置裁剪的座標位置
        x, y, w, h = 363, 0, 1718, 1718

        # 裁剪圖片
        cropped_image = image_rgb[y:y+h, x:x+w]

        # 調整圖片大小
        resized_image = cv2.resize(cropped_image, (1024, 1024))

        target_path = os.path.join(target_folder, filename)
        cv2.imwrite(target_path, cv2.cvtColor(resized_image, cv2.COLOR_RGB2BGR))

print("處理完成，所有圖片已保存至", target_folder)

# %% [markdown]
# ## Resized images

# %%
import cv2
import os
import numpy as np

source_folder = './Inpainting_result/Inpainting_result/'
target_folder = './Inpainting__new/'

if not os.path.exists(target_folder):
    os.makedirs(target_folder)

for filename in os.listdir(source_folder):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
        image_path = os.path.join(source_folder, filename)
        image = cv2.imread(image_path)

        if image is None:
            continue

        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # 調整圖片大小
        resized_image = cv2.resize(image_rgb, (256, 256))

        target_path = os.path.join(target_folder, filename)
        cv2.imwrite(target_path, cv2.cvtColor(resized_image, cv2.COLOR_RGB2BGR))

print("處理完成，所有圖片已保存至", target_folder)

# %% [markdown]
# ## Rename the Images

# %%
import os

def rename_images_sequentially(folder_path):
    image_extensions = ['.jpg', '.jpeg', '.png', '.bmp', '.gif']  # 支持的圖片格式
    files = [file for file in os.listdir(folder_path) if any(file.lower().endswith(ext) for ext in image_extensions)]
    files.sort()

    # 重新命名
    for index, filename in enumerate(files, start=1):

        # 得到檔案的副檔名
        ext = os.path.splitext(filename)[1]

        # 生成新的文件名
        new_filename = f"{index}{ext}"
        
        old_file = os.path.join(folder_path, filename)
        new_file = os.path.join(folder_path, new_filename)

        # 重新命名文件
        os.rename(old_file, new_file)
        print(f"Renamed '{filename}' to '{new_filename}'")

folder_path = 'noacne_white_background_1024_1024_541'
rename_images_sequentially(folder_path)
# Out:
# Renamed 'CFD-AF-200-228-N.jpg' to '1.jpg'
# Renamed 'CFD-AF-201-060-N.jpg' to '2.jpg'
# Renamed 'CFD-AF-203-077-N.jpg' to '3.jpg'
# Renamed 'CFD-AF-204-067-N.jpg' to '4.jpg'
# Renamed 'CFD-AF-205-155-N.jpg' to '5.jpg'
# Renamed 'CFD-AF-206-079-N.jpg' to '6.jpg'
# Renamed 'CFD-AF-207-023-N.jpg' to '7.jpg'
# Renamed 'CFD-AF-208-003-N.jpg' to '8.jpg'
# Renamed 'CFD-AF-209-006-N.jpg' to '9.jpg'
# Renamed 'CFD-AF-212-097-N.jpg' to '10.jpg'
# Renamed 'CFD-AF-213-126-N.jpg' to '11.jpg'
# Renamed 'CFD-AF-215-70-N.jpg' to '12.jpg'
# Renamed 'CFD-AF-216-106-N.jpg' to '13.jpg'
# Renamed 'CFD-AF-219-106-N.jpg' to '14.jpg'
# Renamed 'CFD-AF-220-107-N.jpg' to '15.jpg'
# Renamed 'CFD-AF-221-147-N.jpg' to '16.jpg'
# Renamed 'CFD-AF-222-134-N.jpg' to '17.jpg'
# Renamed 'CFD-AF-224-026-N.jpg' to '18.jpg'
# Renamed 'CFD-AF-225-141-N.jpg' to '19.jpg'
# Renamed 'CFD-AF-227-207-N.jpg' to '20.jpg'
# Renamed 'CFD-AF-228-173-N.jpg' to '21.jpg'
# Renamed 'CFD-AF-229-160-N.jpg' to '22.jpg'
# Renamed 'CFD-AF-230-193-N.jpg' to '23.jpg'
# Renamed 'CFD-AF-232-078-N.jpg' to '24.jpg'
# Renamed 'CFD-AF-233-190-N.jpg' to '25.jpg'
# Renamed 'CFD-AF-234-208-N.jpg' to '26.jpg'
# Renamed 'CFD-AF-235-170-N.jpg' to '27.jpg'
# Renamed 'CFD-AF-236-145-N.jpg' to '28.jpg'
# Renamed 'CFD-AF-237-223-N.jpg' to '29.jpg'
# Renamed 'CFD-AF-238-185-N.jpg' to '30.jpg'
# Renamed 'CFD-AF-239-171-N.jpg' to '31.jpg'
# Renamed 'CFD-AF-240-206-N.jpg' to '32.jpg'
# Renamed 'CFD-AF-241-141-N.jpg' to '33.jpg'
# Renamed 'CFD-AF-243-170-N.jpg' to '34.jpg'
# Renamed 'CFD-AF-244-168-N.jpg' to '35.jpg'
# Renamed 'CFD-AF-245-143-N.jpg' to '36.jpg'
# Renamed 'CFD-AF-246-242-N.jpg' to '37.jpg'
# Renamed 'CFD-AF-249-092-N.jpg' to '38.jpg'
# Renamed 'CFD-AF-250-200-N.jpg' to '39.jpg'
# Renamed 'CFD-AF-251-093-N.jpg' to '40.jpg'
# Renamed 'CFD-AF-253-130-N.jpg' to '41.jpg'
# Renamed 'CFD-AF-255-209-N.jpg' to '42.jpg'
# Renamed 'CFD-AM-201-076-N.jpg' to '43.jpg'
# Renamed 'CFD-AM-202-079-N.jpg' to '44.jpg'
# Renamed 'CFD-AM-203-086-N.jpg' to '45.jpg'
# Renamed 'CFD-AM-204-122-N.jpg' to '46.jpg'
# Renamed 'CFD-AM-205-153-N.jpg' to '47.jpg'
# Renamed 'CFD-AM-207-108-N.jpg' to '48.jpg'
# Renamed 'CFD-AM-210-035-N.jpg' to '49.jpg'
# Renamed 'CFD-AM-211-052-N.jpg' to '50.jpg'
# Renamed 'CFD-AM-212-050-N.jpg' to '51.jpg'
# Renamed 'CFD-AM-213-056-N.jpg' to '52.jpg'
# Renamed 'CFD-AM-214-168-N.jpg' to '53.jpg'
# Renamed 'CFD-AM-215-120-N.jpg' to '54.jpg'
# Renamed 'CFD-AM-216-114-N.jpg' to '55.jpg'
# Renamed 'CFD-AM-217-085-N.jpg' to '56.jpg'
# Renamed 'CFD-AM-218-085-N.jpg' to '57.jpg'
# Renamed 'CFD-AM-219-101-N.jpg' to '58.jpg'
# Renamed 'CFD-AM-221-184-N.jpg' to '59.jpg'
# Renamed 'CFD-AM-224-126-N.jpg' to '60.jpg'
# Renamed 'CFD-AM-225-102-N.jpg' to '61.jpg'
# Renamed 'CFD-AM-227-184-N.jpg' to '62.jpg'
# Renamed 'CFD-AM-228-214-N.jpg' to '63.jpg'
# Renamed 'CFD-AM-229-224-N.jpg' to '64.jpg'
# Renamed 'CFD-AM-230-150-N.jpg' to '65.jpg'
# Renamed 'CFD-AM-231-136-N.jpg' to '66.jpg'
# Renamed 'CFD-AM-234-355-N.jpg' to '67.jpg'
# Renamed 'CFD-AM-235-241-N.jpg' to '68.jpg'
# Renamed 'CFD-AM-236-090-N.jpg' to '69.jpg'
# Renamed 'CFD-AM-237-154-N.jpg' to '70.jpg'
# Renamed 'CFD-AM-238-269-N.jpg' to '71.jpg'
# Renamed 'CFD-AM-240-191-N.jpg' to '72.jpg'
# Renamed 'CFD-AM-243-212-N.jpg' to '73.jpg'
# Renamed 'CFD-AM-244-222-N.jpg' to '74.jpg'
# Renamed 'CFD-AM-245-111-N.jpg' to '75.jpg'
# Renamed 'CFD-AM-247-165-N.jpg' to '76.jpg'
# Renamed 'CFD-AM-248-104-N.jpg' to '77.jpg'
# Renamed 'CFD-AM-249-163-N.jpg' to '78.jpg'
# Renamed 'CFD-AM-253-161-N.jpg' to '79.jpg'
# Renamed 'CFD-BF-001-009-F.jpg' to '80.jpg'
# Renamed 'CFD-BF-001-018-HO.jpg' to '81.jpg'
# Renamed 'CFD-BF-001-021-HC.jpg' to '82.jpg'
# Renamed 'CFD-BF-001-025-N.jpg' to '83.jpg'
# Renamed 'CFD-BF-001-026-A.jpg' to '84.jpg'
# Renamed 'CFD-BF-002-001-N.jpg' to '85.jpg'
# Renamed 'CFD-BF-002-004-HO.jpg' to '86.jpg'
# Renamed 'CFD-BF-002-006-HC.jpg' to '87.jpg'
# Renamed 'CFD-BF-002-018-A.jpg' to '88.jpg'
# Renamed 'CFD-BF-002-022-F.jpg' to '89.jpg'
# Renamed 'CFD-BF-003-003-N.jpg' to '90.jpg'
# Renamed 'CFD-BF-005-001-N.jpg' to '91.jpg'
# Renamed 'CFD-BF-005-005-HO.jpg' to '92.jpg'
# Renamed 'CFD-BF-005-010-HC.jpg' to '93.jpg'
# Renamed 'CFD-BF-005-020-A.jpg' to '94.jpg'
# Renamed 'CFD-BF-005-022-F.jpg' to '95.jpg'
# Renamed 'CFD-BF-007-001-N.jpg' to '96.jpg'
# Renamed 'CFD-BF-007-004-HO.jpg' to '97.jpg'
# Renamed 'CFD-BF-007-006-HC.jpg' to '98.jpg'
# Renamed 'CFD-BF-007-013-A.jpg' to '99.jpg'
# Renamed 'CFD-BF-007-024-F.jpg' to '100.jpg'
# Renamed 'CFD-BF-008-001-N.jpg' to '101.jpg'
# Renamed 'CFD-BF-008-003-HO.jpg' to '102.jpg'
# Renamed 'CFD-BF-008-018-F.jpg' to '103.jpg'
# Renamed 'CFD-BF-013-001-N.jpg' to '104.jpg'
# Renamed 'CFD-BF-013-003-HO.jpg' to '105.jpg'
# Renamed 'CFD-BF-013-005-HC.jpg' to '106.jpg'
# Renamed 'CFD-BF-013-017-A.jpg' to '107.jpg'
# Renamed 'CFD-BF-013-026-F.jpg' to '108.jpg'
# Renamed 'CFD-BF-014-002-N.jpg' to '109.jpg'
# Renamed 'CFD-BF-014-004-HO.jpg' to '110.jpg'
# Renamed 'CFD-BF-014-005-HC.jpg' to '111.jpg'
# Renamed 'CFD-BF-014-013-A.jpg' to '112.jpg'
# Renamed 'CFD-BF-015-004-N.jpg' to '113.jpg'
# Renamed 'CFD-BF-015-006-HO.jpg' to '114.jpg'
# Renamed 'CFD-BF-015-007-HC.jpg' to '115.jpg'
# Renamed 'CFD-BF-015-022-A.jpg' to '116.jpg'
# Renamed 'CFD-BF-015-025-F.jpg' to '117.jpg'
# Renamed 'CFD-BF-016-017-N.jpg' to '118.jpg'
# Renamed 'CFD-BF-016-018-HO.jpg' to '119.jpg'
# Renamed 'CFD-BF-016-019-HC.jpg' to '120.jpg'
# Renamed 'CFD-BF-016-020-A.jpg' to '121.jpg'
# Renamed 'CFD-BF-016-021-F.jpg' to '122.jpg'
# Renamed 'CFD-BF-017-003-N.jpg' to '123.jpg'
# Renamed 'CFD-BF-017-004-HO.jpg' to '124.jpg'
# Renamed 'CFD-BF-017-007-HC.jpg' to '125.jpg'
# Renamed 'CFD-BF-017-011-A.jpg' to '126.jpg'
# Renamed 'CFD-BF-017-016-F.jpg' to '127.jpg'
# Renamed 'CFD-BF-018-019-A.jpg' to '128.jpg'
# Renamed 'CFD-BF-018-039-N.jpg' to '129.jpg'
# Renamed 'CFD-BF-018-040-HO.jpg' to '130.jpg'
# Renamed 'CFD-BF-018-041-HC.jpg' to '131.jpg'
# Renamed 'CFD-BF-018-044-F.jpg' to '132.jpg'
# Renamed 'CFD-BF-023-003-HO.jpg' to '133.jpg'
# Renamed 'CFD-BF-023-010-N.jpg' to '134.jpg'
# Renamed 'CFD-BF-023-012-HC.jpg' to '135.jpg'
# Renamed 'CFD-BF-023-013-A.jpg' to '136.jpg'
# Renamed 'CFD-BF-023-014-F.jpg' to '137.jpg'
# Renamed 'CFD-BF-025-002-N.jpg' to '138.jpg'
# Renamed 'CFD-BF-025-005-HO.jpg' to '139.jpg'
# Renamed 'CFD-BF-025-011-A.jpg' to '140.jpg'
# Renamed 'CFD-BF-025-018-HC.jpg' to '141.jpg'
# Renamed 'CFD-BF-025-020-F.jpg' to '142.jpg'
# Renamed 'CFD-BF-027-002-N.jpg' to '143.jpg'
# Renamed 'CFD-BF-027-006-HO.jpg' to '144.jpg'
# Renamed 'CFD-BF-027-008-A.jpg' to '145.jpg'
# Renamed 'CFD-BF-027-013-HC.jpg' to '146.jpg'
# Renamed 'CFD-BF-027-016-F.jpg' to '147.jpg'
# Renamed 'CFD-BF-028-001-N.jpg' to '148.jpg'
# Renamed 'CFD-BF-028-006-HO.jpg' to '149.jpg'
# Renamed 'CFD-BF-028-020-HC.jpg' to '150.jpg'
# Renamed 'CFD-BF-028-021-A.jpg' to '151.jpg'
# Renamed 'CFD-BF-028-029-F.jpg' to '152.jpg'
# Renamed 'CFD-BF-031-002-N.jpg' to '153.jpg'
# Renamed 'CFD-BF-031-020-A.jpg' to '154.jpg'
# Renamed 'CFD-BF-031-048-HC.jpg' to '155.jpg'
# Renamed 'CFD-BF-031-051-HO.jpg' to '156.jpg'
# Renamed 'CFD-BF-031-062-F.jpg' to '157.jpg'
# Renamed 'CFD-BF-037-013-A.jpg' to '158.jpg'
# Renamed 'CFD-BF-037-022-N.jpg' to '159.jpg'
# Renamed 'CFD-BF-037-026-HO.jpg' to '160.jpg'
# Renamed 'CFD-BF-037-030-HC.jpg' to '161.jpg'
# Renamed 'CFD-BF-037-043-F.jpg' to '162.jpg'
# Renamed 'CFD-BF-040-003-N.jpg' to '163.jpg'
# Renamed 'CFD-BF-040-010-HC.jpg' to '164.jpg'
# Renamed 'CFD-BF-040-043-HO.jpg' to '165.jpg'
# Renamed 'CFD-BF-040-051-A.jpg' to '166.jpg'
# Renamed 'CFD-BF-040-081-F.jpg' to '167.jpg'
# Renamed 'CFD-BF-041-001-N.jpg' to '168.jpg'
# Renamed 'CFD-BF-041-004-HO.jpg' to '169.jpg'
# Renamed 'CFD-BF-041-018-F.jpg' to '170.jpg'
# Renamed 'CFD-BF-041-038-HC.jpg' to '171.jpg'
# Renamed 'CFD-BF-041-047-A.jpg' to '172.jpg'
# Renamed 'CFD-BF-050-003-N.jpg' to '173.jpg'
# Renamed 'CFD-BF-050-004-HO.jpg' to '174.jpg'
# Renamed 'CFD-BF-050-008-HC.jpg' to '175.jpg'
# Renamed 'CFD-BF-050-012-A.jpg' to '176.jpg'
# Renamed 'CFD-BF-050-036-F.jpg' to '177.jpg'
# Renamed 'CFD-BF-201-080-N.jpg' to '178.jpg'
# Renamed 'CFD-BF-202-109-N.jpg' to '179.jpg'
# Renamed 'CFD-BF-204-189-N.jpg' to '180.jpg'
# Renamed 'CFD-BF-207-004-N.jpg' to '181.jpg'
# Renamed 'CFD-BF-208-266-N.jpg' to '182.jpg'
# Renamed 'CFD-BF-212-315-N.jpg' to '183.jpg'
# Renamed 'CFD-BF-215-177-N.jpg' to '184.jpg'
# Renamed 'CFD-BF-216-132-N.jpg' to '185.jpg'
# Renamed 'CFD-BF-217-189-N.jpg' to '186.jpg'
# Renamed 'CFD-BF-218-207-N.jpg' to '187.jpg'
# Renamed 'CFD-BF-221-223-N.jpg' to '188.jpg'
# Renamed 'CFD-BF-223-250-N.jpg' to '189.jpg'
# Renamed 'CFD-BF-226-119-N.jpg' to '190.jpg'
# Renamed 'CFD-BF-229-179-N.jpg' to '191.jpg'
# Renamed 'CFD-BF-241-222-N.jpg' to '192.jpg'
# Renamed 'CFD-BF-242-154-N.jpg' to '193.jpg'
# Renamed 'CFD-BF-244-231-N.jpg' to '194.jpg'
# Renamed 'CFD-BF-250-121-N.jpg' to '195.jpg'
# Renamed 'CFD-BF-251-211-N.jpg' to '196.jpg'
# Renamed 'CFD-BF-253-202-N.jpg' to '197.jpg'
# Renamed 'CFD-BM-003-003-N.jpg' to '198.jpg'
# Renamed 'CFD-BM-003-021-HO.jpg' to '199.jpg'
# Renamed 'CFD-BM-003-030-A.jpg' to '200.jpg'
# Renamed 'CFD-BM-003-031-F.jpg' to '201.jpg'
# Renamed 'CFD-BM-012-018-N.jpg' to '202.jpg'
# Renamed 'CFD-BM-013-002-N.jpg' to '203.jpg'
# Renamed 'CFD-BM-013-004-HO.jpg' to '204.jpg'
# Renamed 'CFD-BM-013-014-HC.jpg' to '205.jpg'
# Renamed 'CFD-BM-013-016-A.jpg' to '206.jpg'
# Renamed 'CFD-BM-013-019-F.jpg' to '207.jpg'
# Renamed 'CFD-BM-015-012-A.jpg' to '208.jpg'
# Renamed 'CFD-BM-015-014-F.jpg' to '209.jpg'
# Renamed 'CFD-BM-015-015-N.jpg' to '210.jpg'
# Renamed 'CFD-BM-015-016-HO.jpg' to '211.jpg'
# Renamed 'CFD-BM-015-017-HC.jpg' to '212.jpg'
# Renamed 'CFD-BM-016-030-F.jpg' to '213.jpg'
# Renamed 'CFD-BM-016-036-N.jpg' to '214.jpg'
# Renamed 'CFD-BM-016-040-HO.jpg' to '215.jpg'
# Renamed 'CFD-BM-016-042-A.jpg' to '216.jpg'
# Renamed 'CFD-BM-021-009-HC.jpg' to '217.jpg'
# Renamed 'CFD-BM-021-021-N.jpg' to '218.jpg'
# Renamed 'CFD-BM-021-022-HO.jpg' to '219.jpg'
# Renamed 'CFD-BM-021-026-A.jpg' to '220.jpg'
# Renamed 'CFD-BM-021-029-F.jpg' to '221.jpg'
# Renamed 'CFD-BM-027-001-N.jpg' to '222.jpg'
# Renamed 'CFD-BM-028-002-N.jpg' to '223.jpg'
# Renamed 'CFD-BM-028-012-A.jpg' to '224.jpg'
# Renamed 'CFD-BM-028-028-HO.jpg' to '225.jpg'
# Renamed 'CFD-BM-028-031-HC.jpg' to '226.jpg'
# Renamed 'CFD-BM-028-050-F.jpg' to '227.jpg'
# Renamed 'CFD-BM-031-003-N.jpg' to '228.jpg'
# Renamed 'CFD-BM-031-004-HO.jpg' to '229.jpg'
# Renamed 'CFD-BM-031-009-HC.jpg' to '230.jpg'
# Renamed 'CFD-BM-031-030-A.jpg' to '231.jpg'
# Renamed 'CFD-BM-031-034-F.jpg' to '232.jpg'
# Renamed 'CFD-BM-036-003-N.jpg' to '233.jpg'
# Renamed 'CFD-BM-036-004-HO.jpg' to '234.jpg'
# Renamed 'CFD-BM-036-007-HC.jpg' to '235.jpg'
# Renamed 'CFD-BM-036-037-A.jpg' to '236.jpg'
# Renamed 'CFD-BM-036-045-F.jpg' to '237.jpg'
# Renamed 'CFD-BM-037-033-N.jpg' to '238.jpg'
# Renamed 'CFD-BM-037-036-HO.jpg' to '239.jpg'
# Renamed 'CFD-BM-037-038-HC.jpg' to '240.jpg'
# Renamed 'CFD-BM-037-041-A.jpg' to '241.jpg'
# Renamed 'CFD-BM-037-088-F.jpg' to '242.jpg'
# Renamed 'CFD-BM-039-029-N.jpg' to '243.jpg'
# Renamed 'CFD-BM-039-031-HC.jpg' to '244.jpg'
# Renamed 'CFD-BM-039-034-HO.jpg' to '245.jpg'
# Renamed 'CFD-BM-039-037-A.jpg' to '246.jpg'
# Renamed 'CFD-BM-039-044-F.jpg' to '247.jpg'
# Renamed 'CFD-BM-043-014-A.jpg' to '248.jpg'
# Renamed 'CFD-BM-043-071-N.jpg' to '249.jpg'
# Renamed 'CFD-BM-043-072-HC.jpg' to '250.jpg'
# Renamed 'CFD-BM-043-076-HO.jpg' to '251.jpg'
# Renamed 'CFD-BM-046-006-N.jpg' to '252.jpg'
# Renamed 'CFD-BM-046-039-HO.jpg' to '253.jpg'
# Renamed 'CFD-BM-046-042-HC.jpg' to '254.jpg'
# Renamed 'CFD-BM-046-048-A.jpg' to '255.jpg'
# Renamed 'CFD-BM-046-063-F.jpg' to '256.jpg'
# Renamed 'CFD-BM-201-077-N.jpg' to '257.jpg'
# Renamed 'CFD-BM-202-063-N.jpg' to '258.jpg'
# Renamed 'CFD-BM-204-003-N.jpg' to '259.jpg'
# Renamed 'CFD-BM-206-114-N.jpg' to '260.jpg'
# Renamed 'CFD-BM-207-024-N.jpg' to '261.jpg'
# Renamed 'CFD-BM-208-065-N.jpg' to '262.jpg'
# Renamed 'CFD-BM-209-088-N.jpg' to '263.jpg'
# Renamed 'CFD-BM-214-075-N.jpg' to '264.jpg'
# Renamed 'CFD-BM-224-073-N.jpg' to '265.jpg'
# Renamed 'CFD-BM-226-276-N.jpg' to '266.jpg'
# Renamed 'CFD-BM-227-191-N.jpg' to '267.jpg'
# Renamed 'CFD-BM-235-226-N.jpg' to '268.jpg'
# Renamed 'CFD-BM-239-136-N.jpg' to '269.jpg'
# Renamed 'CFD-BM-240-207-N.jpg' to '270.jpg'
# Renamed 'CFD-BM-246-192-N.jpg' to '271.jpg'
# Renamed 'CFD-BM-247-240-N.jpg' to '272.jpg'
# Renamed 'CFD-BM-248-128-N.jpg' to '273.jpg'
# Renamed 'CFD-BM-249-235-N.jpg' to '274.jpg'
# Renamed 'CFD-IF-610-766-N.jpg' to '275.jpg'
# Renamed 'CFD-IF-614-107-N.jpg' to '276.jpg'
# Renamed 'CFD-IF-620-218-N.jpg' to '277.jpg'
# Renamed 'CFD-IF-623-129-N.jpg' to '278.jpg'
# Renamed 'CFD-IF-626-375-N.jpg' to '279.jpg'
# Renamed 'CFD-IF-631-363-N.jpg' to '280.jpg'
# Renamed 'CFD-IF-633-012-N.jpg' to '281.jpg'
# Renamed 'CFD-IF-642-295-N.jpg' to '282.jpg'
# Renamed 'CFD-IF-660-464-N.jpg' to '283.jpg'
# Renamed 'CFD-IF-710-016-N.jpg' to '284.jpg'
# Renamed 'CFD-IF-718-001-N.jpg' to '285.jpg'
# Renamed 'CFD-IF-734-108-N.jpg' to '286.jpg'
# Renamed 'CFD-IF-735-353-N.jpg' to '287.jpg'
# Renamed 'CFD-IM-603-305-N.jpg' to '288.jpg'
# Renamed 'CFD-IM-611-306-N.jpg' to '289.jpg'
# Renamed 'CFD-IM-627-178-N.jpg' to '290.jpg'
# Renamed 'CFD-IM-628-176-N.jpg' to '291.jpg'
# Renamed 'CFD-IM-637-007-N.jpg' to '292.jpg'
# Renamed 'CFD-IM-653-008-N.jpg' to '293.jpg'
# Renamed 'CFD-IM-658-284-N.jpg' to '294.jpg'
# Renamed 'CFD-IM-662-171-N.jpg' to '295.jpg'
# Renamed 'CFD-IM-663-230-N.jpg' to '296.jpg'
# Renamed 'CFD-IM-675-015-N.jpg' to '297.jpg'
# Renamed 'CFD-IM-678-482-N.jpg' to '298.jpg'
# Renamed 'CFD-IM-683-231-N.jpg' to '299.jpg'
# Renamed 'CFD-IM-692-011-N.jpg' to '300.jpg'
# Renamed 'CFD-IM-694-297-N.jpg' to '301.jpg'
# Renamed 'CFD-IM-698-011-N.jpg' to '302.jpg'
# Renamed 'CFD-IM-702-101-N.jpg' to '303.jpg'
# Renamed 'CFD-IM-712-005-N.jpg' to '304.jpg'
# Renamed 'CFD-IM-715-013-N.jpg' to '305.jpg'
# Renamed 'CFD-IM-719-221-N.jpg' to '306.jpg'
# Renamed 'CFD-IM-725-142-N.jpg' to '307.jpg'
# Renamed 'CFD-IM-726-248-N.jpg' to '308.jpg'
# Renamed 'CFD-LF-201-035-N.jpg' to '309.jpg'
# Renamed 'CFD-LF-202-065-N.jpg' to '310.jpg'
# Renamed 'CFD-LF-205-100-N.jpg' to '311.jpg'
# Renamed 'CFD-LF-207-198-N.jpg' to '312.jpg'
# Renamed 'CFD-LF-209-072-N.jpg' to '313.jpg'
# Renamed 'CFD-LF-212-066-N.jpg' to '314.jpg'
# Renamed 'CFD-LF-213-079-N.jpg' to '315.jpg'
# Renamed 'CFD-LF-216-121-N.jpg' to '316.jpg'
# Renamed 'CFD-LF-217-082-N.jpg' to '317.jpg'
# Renamed 'CFD-LF-219-223-N.jpg' to '318.jpg'
# Renamed 'CFD-LF-220-120-N.jpg' to '319.jpg'
# Renamed 'CFD-LF-235-219-N.jpg' to '320.jpg'
# Renamed 'CFD-LF-239-148-N.jpg' to '321.jpg'
# Renamed 'CFD-LF-240-199-N.jpg' to '322.jpg'
# Renamed 'CFD-LF-241-188-N.jpg' to '323.jpg'
# Renamed 'CFD-LF-242-121-N.jpg' to '324.jpg'
# Renamed 'CFD-LF-245-166-N.jpg' to '325.jpg'
# Renamed 'CFD-LF-246-129-N.jpg' to '326.jpg'
# Renamed 'CFD-LF-249-132-N.jpg' to '327.jpg'
# Renamed 'CFD-LM-212-143-N.jpg' to '328.jpg'
# Renamed 'CFD-LM-214-165-N.jpg' to '329.jpg'
# Renamed 'CFD-LM-217-162-N.jpg' to '330.jpg'
# Renamed 'CFD-LM-220-329-N.jpg' to '331.jpg'
# Renamed 'CFD-LM-221-216-N.jpg' to '332.jpg'
# Renamed 'CFD-LM-225-130-N.jpg' to '333.jpg'
# Renamed 'CFD-LM-227-103-N.jpg' to '334.jpg'
# Renamed 'CFD-LM-228-188-N.jpg' to '335.jpg'
# Renamed 'CFD-LM-233-171-N.jpg' to '336.jpg'
# Renamed 'CFD-LM-234-176-N.jpg' to '337.jpg'
# Renamed 'CFD-LM-239-075-N.jpg' to '338.jpg'
# Renamed 'CFD-LM-241-125-N.jpg' to '339.jpg'
# Renamed 'CFD-LM-243-075-N.jpg' to '340.jpg'
# Renamed 'CFD-MF-304-018-N.jpg' to '341.jpg'
# Renamed 'CFD-MF-305-014-N.jpg' to '342.jpg'
# Renamed 'CFD-MF-306-003-N.jpg' to '343.jpg'
# Renamed 'CFD-MF-308-001-N.jpg' to '344.jpg'
# Renamed 'CFD-MF-309-002-N.jpg' to '345.jpg'
# Renamed 'CFD-MF-311-001-N.jpg' to '346.jpg'
# Renamed 'CFD-MF-313-002-N.jpg' to '347.jpg'
# Renamed 'CFD-MF-314-001-N.jpg' to '348.jpg'
# Renamed 'CFD-MF-318-022-N.jpg' to '349.jpg'
# Renamed 'CFD-MF-324-031-N.jpg' to '350.jpg'
# Renamed 'CFD-MF-326-016-N.jpg' to '351.jpg'
# Renamed 'CFD-MF-327-002-N.jpg' to '352.jpg'
# Renamed 'CFD-MF-335-002-N.jpg' to '353.jpg'
# Renamed 'CFD-MF-336-016-N.jpg' to '354.jpg'
# Renamed 'CFD-MF-338-001-N.jpg' to '355.jpg'
# Renamed 'CFD-MF-339-002-N.jpg' to '356.jpg'
# Renamed 'CFD-MF-348-018-N.jpg' to '357.jpg'
# Renamed 'CFD-MF-352-054-N.jpg' to '358.jpg'
# Renamed 'CFD-MF-354-067-N.jpg' to '359.jpg'
# Renamed 'CFD-MF-355-022-N.jpg' to '360.jpg'
# Renamed 'CFD-MF-357-002-N.jpg' to '361.jpg'
# Renamed 'CFD-MF-358-001-N.jpg' to '362.jpg'
# Renamed 'CFD-MF-360-106-N.jpg' to '363.jpg'
# Renamed 'CFD-MM-300-035-N.jpg' to '364.jpg'
# Renamed 'CFD-MM-309-027-N.jpg' to '365.jpg'
# Renamed 'CFD-MM-310-001-N.jpg' to '366.jpg'
# Renamed 'CFD-MM-314-062-N.jpg' to '367.jpg'
# Renamed 'CFD-MM-315-013-N.jpg' to '368.jpg'
# Renamed 'CFD-MM-316-156-N.jpg' to '369.jpg'
# Renamed 'CFD-MM-317-061-N.jpg' to '370.jpg'
# Renamed 'CFD-WF-007-001-N.jpg' to '371.jpg'
# Renamed 'CFD-WF-007-003-HO.jpg' to '372.jpg'
# Renamed 'CFD-WF-007-005-HC.jpg' to '373.jpg'
# Renamed 'CFD-WF-007-026-F.jpg' to '374.jpg'
# Renamed 'CFD-WF-007-029-A.jpg' to '375.jpg'
# Renamed 'CFD-WF-012-002-N.jpg' to '376.jpg'
# Renamed 'CFD-WF-012-004-HC.jpg' to '377.jpg'
# Renamed 'CFD-WF-012-007-HO.jpg' to '378.jpg'
# Renamed 'CFD-WF-012-012-A.jpg' to '379.jpg'
# Renamed 'CFD-WF-012-017-F.jpg' to '380.jpg'
# Renamed 'CFD-WF-014-002-N.jpg' to '381.jpg'
# Renamed 'CFD-WF-014-004-HO.jpg' to '382.jpg'
# Renamed 'CFD-WF-014-009-HC.jpg' to '383.jpg'
# Renamed 'CFD-WF-014-012-A.jpg' to '384.jpg'
# Renamed 'CFD-WF-014-023-F.jpg' to '385.jpg'
# Renamed 'CFD-WF-015-006-N.jpg' to '386.jpg'
# Renamed 'CFD-WF-015-014-A.jpg' to '387.jpg'
# Renamed 'CFD-WF-015-022-HO.jpg' to '388.jpg'
# Renamed 'CFD-WF-015-023-HC.jpg' to '389.jpg'
# Renamed 'CFD-WF-015-027-F.jpg' to '390.jpg'
# Renamed 'CFD-WF-017-003-N.jpg' to '391.jpg'
# Renamed 'CFD-WF-017-012-F.jpg' to '392.jpg'
# Renamed 'CFD-WF-017-015-HO.jpg' to '393.jpg'
# Renamed 'CFD-WF-017-016-HC.jpg' to '394.jpg'
# Renamed 'CFD-WF-017-023-A.jpg' to '395.jpg'
# Renamed 'CFD-WF-020-002-N.jpg' to '396.jpg'
# Renamed 'CFD-WF-020-007-HC.jpg' to '397.jpg'
# Renamed 'CFD-WF-020-012-A.jpg' to '398.jpg'
# Renamed 'CFD-WF-020-023-HO.jpg' to '399.jpg'
# Renamed 'CFD-WF-020-027-F.jpg' to '400.jpg'
# Renamed 'CFD-WF-022-007-HC.jpg' to '401.jpg'
# Renamed 'CFD-WF-022-014-F.jpg' to '402.jpg'
# Renamed 'CFD-WF-022-017-N.jpg' to '403.jpg'
# Renamed 'CFD-WF-022-019-HO.jpg' to '404.jpg'
# Renamed 'CFD-WF-022-023-A.jpg' to '405.jpg'
# Renamed 'CFD-WF-023-003-N.jpg' to '406.jpg'
# Renamed 'CFD-WF-023-013-A.jpg' to '407.jpg'
# Renamed 'CFD-WF-023-020-HO.jpg' to '408.jpg'
# Renamed 'CFD-WF-023-021-HC.jpg' to '409.jpg'
# Renamed 'CFD-WF-023-026-F.jpg' to '410.jpg'
# Renamed 'CFD-WF-024-003-N.jpg' to '411.jpg'
# Renamed 'CFD-WF-024-006-HO.jpg' to '412.jpg'
# Renamed 'CFD-WF-024-010-HC.jpg' to '413.jpg'
# Renamed 'CFD-WF-024-029-A.jpg' to '414.jpg'
# Renamed 'CFD-WF-024-031-F.jpg' to '415.jpg'
# Renamed 'CFD-WF-027-003-N.jpg' to '416.jpg'
# Renamed 'CFD-WF-027-007-HC.jpg' to '417.jpg'
# Renamed 'CFD-WF-027-014-A.jpg' to '418.jpg'
# Renamed 'CFD-WF-027-015-F.jpg' to '419.jpg'
# Renamed 'CFD-WF-027-021-HO.jpg' to '420.jpg'
# Renamed 'CFD-WF-029-002-N.jpg' to '421.jpg'
# Renamed 'CFD-WF-029-018-F.jpg' to '422.jpg'
# Renamed 'CFD-WF-029-021-HO.jpg' to '423.jpg'
# Renamed 'CFD-WF-029-023-HC.jpg' to '424.jpg'
# Renamed 'CFD-WF-029-026-A.jpg' to '425.jpg'
# Renamed 'CFD-WF-038-021-N.jpg' to '426.jpg'
# Renamed 'CFD-WF-038-023-HO.jpg' to '427.jpg'
# Renamed 'CFD-WF-038-027-HC.jpg' to '428.jpg'
# Renamed 'CFD-WF-038-030-A.jpg' to '429.jpg'
# Renamed 'CFD-WF-038-033-F.jpg' to '430.jpg'
# Renamed 'CFD-WF-039-005-HO.jpg' to '431.jpg'
# Renamed 'CFD-WF-039-008-HC.jpg' to '432.jpg'
# Renamed 'CFD-WF-039-025-N.jpg' to '433.jpg'
# Renamed 'CFD-WF-039-032-A.jpg' to '434.jpg'
# Renamed 'CFD-WF-039-044-F.jpg' to '435.jpg'
# Renamed 'CFD-WF-200-099-N.jpg' to '436.jpg'
# Renamed 'CFD-WF-209-052-N.jpg' to '437.jpg'
# Renamed 'CFD-WF-211-001-N.jpg' to '438.jpg'
# Renamed 'CFD-WF-213-031-N.jpg' to '439.jpg'
# Renamed 'CFD-WF-218-087-N.jpg' to '440.jpg'
# Renamed 'CFD-WF-224-099-N.jpg' to '441.jpg'
# Renamed 'CFD-WF-231-099-N.jpg' to '442.jpg'
# Renamed 'CFD-WF-232-161-N.jpg' to '443.jpg'
# Renamed 'CFD-WF-236-107-N.jpg' to '444.jpg'
# Renamed 'CFD-WF-237-067-N.jpg' to '445.jpg'
# Renamed 'CFD-WF-243-148-N.jpg' to '446.jpg'
# Renamed 'CFD-WF-246-087-N.jpg' to '447.jpg'
# Renamed 'CFD-WF-249-126-N.jpg' to '448.jpg'
# Renamed 'CFD-WF-252-159-N.jpg' to '449.jpg'
# Renamed 'CFD-WM-004-002-F.jpg' to '450.jpg'
# Renamed 'CFD-WM-004-005-HC.jpg' to '451.jpg'
# Renamed 'CFD-WM-004-006-HO.jpg' to '452.jpg'
# Renamed 'CFD-WM-004-010-N.jpg' to '453.jpg'
# Renamed 'CFD-WM-004-011-A.jpg' to '454.jpg'
# Renamed 'CFD-WM-006-002-N.jpg' to '455.jpg'
# Renamed 'CFD-WM-006-010-HO.jpg' to '456.jpg'
# Renamed 'CFD-WM-006-013-HC.jpg' to '457.jpg'
# Renamed 'CFD-WM-006-022-A.jpg' to '458.jpg'
# Renamed 'CFD-WM-006-039-F.jpg' to '459.jpg'
# Renamed 'CFD-WM-009-002-N.jpg' to '460.jpg'
# Renamed 'CFD-WM-009-004-HO.jpg' to '461.jpg'
# Renamed 'CFD-WM-009-006-HC.jpg' to '462.jpg'
# Renamed 'CFD-WM-009-009-A.jpg' to '463.jpg'
# Renamed 'CFD-WM-009-014-F.jpg' to '464.jpg'
# Renamed 'CFD-WM-014-002-N.jpg' to '465.jpg'
# Renamed 'CFD-WM-014-013-A.jpg' to '466.jpg'
# Renamed 'CFD-WM-014-024-F.jpg' to '467.jpg'
# Renamed 'CFD-WM-016-001-N.jpg' to '468.jpg'
# Renamed 'CFD-WM-016-002-HO.jpg' to '469.jpg'
# Renamed 'CFD-WM-016-005-HC.jpg' to '470.jpg'
# Renamed 'CFD-WM-016-008-A.jpg' to '471.jpg'
# Renamed 'CFD-WM-019-003-N.jpg' to '472.jpg'
# Renamed 'CFD-WM-019-006-HC.jpg' to '473.jpg'
# Renamed 'CFD-WM-019-009-HO.jpg' to '474.jpg'
# Renamed 'CFD-WM-019-013-A.jpg' to '475.jpg'
# Renamed 'CFD-WM-019-017-F.jpg' to '476.jpg'
# Renamed 'CFD-WM-020-001-N.jpg' to '477.jpg'
# Renamed 'CFD-WM-020-003-HO.jpg' to '478.jpg'
# Renamed 'CFD-WM-020-005-HC.jpg' to '479.jpg'
# Renamed 'CFD-WM-020-008-A.jpg' to '480.jpg'
# Renamed 'CFD-WM-020-012-F.jpg' to '481.jpg'
# Renamed 'CFD-WM-021-001-N.jpg' to '482.jpg'
# Renamed 'CFD-WM-021-004-HO.jpg' to '483.jpg'
# Renamed 'CFD-WM-021-006-HC.jpg' to '484.jpg'
# Renamed 'CFD-WM-021-009-A.jpg' to '485.jpg'
# Renamed 'CFD-WM-022-001-N.jpg' to '486.jpg'
# Renamed 'CFD-WM-022-003-HC.jpg' to '487.jpg'
# Renamed 'CFD-WM-022-005-HO.jpg' to '488.jpg'
# Renamed 'CFD-WM-022-008-A.jpg' to '489.jpg'
# Renamed 'CFD-WM-022-012-F.jpg' to '490.jpg'
# Renamed 'CFD-WM-024-003-HO.jpg' to '491.jpg'
# Renamed 'CFD-WM-024-007-HC.jpg' to '492.jpg'
# Renamed 'CFD-WM-024-010-A.jpg' to '493.jpg'
# Renamed 'CFD-WM-024-015-N.jpg' to '494.jpg'
# Renamed 'CFD-WM-024-019-F.jpg' to '495.jpg'
# Renamed 'CFD-WM-029-009-HC.jpg' to '496.jpg'
# Renamed 'CFD-WM-029-014-A.jpg' to '497.jpg'
# Renamed 'CFD-WM-029-020-F.jpg' to '498.jpg'
# Renamed 'CFD-WM-029-023-N.jpg' to '499.jpg'
# Renamed 'CFD-WM-029-029-HO.jpg' to '500.jpg'
# Renamed 'CFD-WM-031-003-N.jpg' to '501.jpg'
# Renamed 'CFD-WM-031-004-HO.jpg' to '502.jpg'
# Renamed 'CFD-WM-031-032-F.jpg' to '503.jpg'
# Renamed 'CFD-WM-031-038-HC.jpg' to '504.jpg'
# Renamed 'CFD-WM-031-045-A.jpg' to '505.jpg'
# Renamed 'CFD-WM-033-006-HC.jpg' to '506.jpg'
# Renamed 'CFD-WM-033-007-HO.jpg' to '507.jpg'
# Renamed 'CFD-WM-033-014-A.jpg' to '508.jpg'
# Renamed 'CFD-WM-033-025-N.jpg' to '509.jpg'
# Renamed 'CFD-WM-033-053-F.jpg' to '510.jpg'
# Renamed 'CFD-WM-039-004-HC.jpg' to '511.jpg'
# Renamed 'CFD-WM-039-008-HO.jpg' to '512.jpg'
# Renamed 'CFD-WM-039-010-A.jpg' to '513.jpg'
# Renamed 'CFD-WM-039-018-N.jpg' to '514.jpg'
# Renamed 'CFD-WM-039-028-F.jpg' to '515.jpg'
# Renamed 'CFD-WM-201-063-N.jpg' to '516.jpg'
# Renamed 'CFD-WM-202-107-N.jpg' to '517.jpg'
# Renamed 'CFD-WM-203-023-N.jpg' to '518.jpg'
# Renamed 'CFD-WM-204-031-N.jpg' to '519.jpg'
# Renamed 'CFD-WM-205-007-N.jpg' to '520.jpg'
# Renamed 'CFD-WM-207-048-N.jpg' to '521.jpg'
# Renamed 'CFD-WM-208-068-N.jpg' to '522.jpg'
# Renamed 'CFD-WM-209-038-N.jpg' to '523.jpg'
# Renamed 'CFD-WM-210-057-N.jpg' to '524.jpg'
# Renamed 'CFD-WM-211-054-N.jpg' to '525.jpg'
# Renamed 'CFD-WM-212-097-N.jpg' to '526.jpg'
# Renamed 'CFD-WM-213-076-N.jpg' to '527.jpg'
# Renamed 'CFD-WM-215-041-N.jpg' to '528.jpg'
# Renamed 'CFD-WM-216-061-N.jpg' to '529.jpg'
# Renamed 'CFD-WM-217-070-N.jpg' to '530.jpg'
# Renamed 'CFD-WM-218-074-N.jpg' to '531.jpg'
# Renamed 'CFD-WM-228-065-N.jpg' to '532.jpg'
# Renamed 'CFD-WM-231-112-N.jpg' to '533.jpg'
# Renamed 'CFD-WM-237-052-N.jpg' to '534.jpg'
# Renamed 'CFD-WM-238-020-N.jpg' to '535.jpg'
# Renamed 'CFD-WM-242-011-N.jpg' to '536.jpg'
# Renamed 'CFD-WM-245-123-N.jpg' to '537.jpg'
# Renamed 'CFD-WM-250-157-N.jpg' to '538.jpg'
# Renamed 'CFD-WM-256-138-N.jpg' to '539.jpg'
# Renamed 'CFD-WM-257-161-N.jpg' to '540.jpg'
# Renamed 'CFD-WM-258-125-N.jpg' to '541.jpg'

# %% [markdown]
# ## Merge two images

# %%
import os
from PIL import Image

def merge_images(image_path1, image_path2, output_path):
    img1 = Image.open(image_path1)
    img2 = Image.open(image_path2)
    if img1.height != img2.height:
        img2 = img2.resize((int(img2.width * img1.height / img2.height), img1.height))
    total_width = img1.width + img2.width
    new_img = Image.new('RGB', (total_width, img1.height))
    new_img.paste(img1, (0, 0))
    new_img.paste(img2, (img1.width, 0))
    new_img.save(output_path)

def process_folders(folder_a, folder_b, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    filenames_a = set(os.listdir(folder_a))
    filenames_b = set(os.listdir(folder_b))

    common_filenames = filenames_a.intersection(filenames_b)  # 找出兩個資料夾中都有的文件名

    for filename in common_filenames:
        file_path_a = os.path.join(folder_a, filename)
        file_path_b = os.path.join(folder_b, filename)
        output_path = os.path.join(output_folder, filename)
        merge_images(file_path_a, file_path_b, output_path)
        print(f"Merged {filename} saved to {output_path}")

folder_a = 'noacne_white_background_1024_1024_541'
folder_b = 'acne_white_background_1024_1024_541'
output_folder = 'aline_noacne2acne_white_background_1024_1024_541'
process_folders(folder_a, folder_b, output_folder)

# %% [markdown]
# ## Change the background color (random)

# %%
import os
import random
from PIL import Image, ImageColor

def get_low_saturation_color():
    # 隨機生成一個低飽和度的顏色
    hue = random.randint(0, 360)  # 色調範圍從0到360
    saturation = random.randint(10, 30)  # 低飽和度範圍從10%到30%
    value = random.randint(50, 90)  # 亮度範圍從50%到90%
    return ImageColor.getrgb(f"hsv({hue}, {saturation}%, {value}%)")

def change_background_color(image_path, output_path, threshold=245):
    img = Image.open(image_path)
    img = img.convert("RGBA")
    new_bg_color = get_low_saturation_color()
    data = img.getdata()
    new_data = []
    for item in data:
        if item[0] > threshold and item[1] > threshold and item[2] > threshold:
            new_data.append(new_bg_color + (item[3],))
        else:
            new_data.append(item)
    img.putdata(new_data)
    img = img.convert("RGB")  # Convert back to RGB before saving
    img.save(output_path)

def process_folder(input_folder, output_folder, threshold=245):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        file_path = os.path.join(input_folder, filename)
        if file_path.lower().endswith(('.png', '.jpg', '.jpeg')):
            output_path = os.path.join(output_folder, filename)
            change_background_color(file_path, output_path, threshold)
            print(f"Processed {filename} with a unique low saturation background.")

input_folder = 'aline_noacne2acne_white_background_1024_1024_541'
output_folder = 'aline_noacne2acne_color_background_1024_1024_541'
process_folder(input_folder, output_folder)
